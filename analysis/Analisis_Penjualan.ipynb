# %%
# Dalam analisis_dasar.ipynb
import pandas as pd

data = pd.DataFrame({
    'nama_barang': ['Beras', 'Minyak', 'Gula', 'Telur', 'Tepung'],
    'jumlah_terjual': [120, 85, 100, 50, 100],
    'satuan': ['kg', 'pcs', 'kg', 'kg'],
    'tanggal': pd.date_range(start='2025-09-01', periods=5, freq='W')
})

#Tampilkan data
print(data)
#Simpan ke file csv
data.to_csv('data/penjualan.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 4
#       1 # Dalam analisis_dasar.ipynb
#       2 import pandas as pd
# ----> 4 data = pd.DataFrame({
#       5     'nama_barang': ['Beras', 'Minyak', 'Gula', 'Telur', 'Tepung'],
#       6     'jumlah_terjual': [120, 85, 100, 50, 100],
#       7     'satuan': ['kg', 'pcs', 'kg', 'kg'],
#       8     'tanggal': pd.date_range(start='2025-09-01', periods=5, freq='W')
#       9 })
#      11 #Tampilkan data
#      12 print(data)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
# ...
